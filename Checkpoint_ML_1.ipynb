# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
import numpy as np
import seaborn as sns
sns.set()

# %% [markdown]
# #PREPROCESSING & DATAVIZ

# %%
house=pd.read_csv((r"C:\Users\KaKone\Downloads\Checkpoint_ML_1\kc_house_data.csv"),encoding='utf-8',sep =",")
house.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
house.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
house.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
 house.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %% [markdown]
# # Feature selection

# %%
def plot_correlation_map( df ):
    
    corr = df.corr()

    s , ax = plt.subplots( figsize =( 14 , 14) )

    cmap = sb.diverging_palette( 220 , 10 , as_cmap = True )

    s = sb.heatmap(

        corr, 

        cmap = cmap,

        square=True, 

        cbar_kws={ 'shrink' : .9 }, 

        ax=ax, 

        annot = True, 

        annot_kws = { 'fontsize' : 9 }

        )

# %%
house.corr()
# Out:
#                      id     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id             1.000000 -0.016762  0.001286   0.005160    -0.012258 -0.132109
# price         -0.016762  1.000000  0.308350   0.525138     0.702035  0.089661
# bedrooms       0.001286  0.308350  1.000000   0.515884     0.576671  0.031703
# bathrooms      0.005160  0.525138  0.515884   1.000000     0.754665  0.087740
# sqft_living   -0.012258  0.702035  0.576671   0.754665     1.000000  0.172826
# sqft_lot      -0.132109  0.089661  0.031703   0.087740     0.172826  1.000000
# floors         0.018525  0.256794  0.175429   0.500653     0.353949 -0.005201
# waterfront    -0.002721  0.266369 -0.006582   0.063744     0.103818  0.021604
# view           0.011592  0.397293  0.079532   0.187737     0.284611  0.074710
# condition     -0.023783  0.036362  0.028472  -0.124982    -0.058753 -0.008958
# grade          0.008130  0.667434  0.356967   0.664983     0.762704  0.113621
# ...

# %%
plot_correlation_map(house)

# %% [markdown]
# # La matrice de corrélation montre une forte correlation entre plusieurs variable à l'exception de: id,Zipcode,waterfront,sqft_basement,yr_renovated,view,condition,lat et long.Nous allons donc proceder à la suppresssion de ces variables.

# %%
plot_correlation_map(house.drop(columns=['id','waterfront','sqft_basement','yr_renovated','view','condition','lat','long','zipcode']))

# %%
house_new=house.drop(columns=['id','date','waterfront','sqft_basement','yr_renovated','view','condition','lat','long','zipcode'], axis=1)
house_new.head()
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  grade  \
# 0  221900.0         3       1.00         1180      5650     1.0      7
# 1  538000.0         3       2.25         2570      7242     2.0      7
# 2  180000.0         2       1.00          770     10000     1.0      6
# 3  604000.0         4       3.00         1960      5000     1.0      7
# 4  510000.0         3       2.00         1680      8080     1.0      8
#
#    sqft_above  yr_built  sqft_living15  sqft_lot15
# 0        1180      1955           1340        5650
# 1        2170      1951           1690        7639
# 2         770      1933           2720        8062
# 3        1050      1965           1360        5000
# 4        1680      1987           1800        7503

# %% [markdown]
# # Dataset Spliting into a training set and a testing set

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics

# %% [markdown]
# # Regression linear simple

# %%
#feature extraction
x1=house_new[["sqft_living"]]
#target_extraction
y1=house_new[["price"]]

# %%
#data spliting avec une taille de 25%
x_train1,x_test1,y_train1,y_test1=train_test_split(x1,y1,test_size=0.25,random_state = 0)

# %%
#Ajustement du modèl
model1=LinearRegression().fit(x_train1,y_train1)
R_carré = model1.score(x_test1, y_test1)
print(f"coefficient of determination: {R_carré}")
# Out:
# coefficient of determination: 0.4830157820838963

# %% [markdown]
# On obtient de coefficient de determination égal à 0,48 , cela veut dire que le modèl predit les resultats à 48%

# %%
x_train1=x_train1.to_numpy()
y_train1=y_train1.to_numpy()

# %%
y_pred = model1.predict(x_test1)

# %%
plt.scatter(x_train1, y_train1, color = "red")
plt.plot(x_train1, model1.predict(x_train1), color = "green")
plt.title("Houses prices vs sqft_living (Training set)")
plt.xlabel("House sqft_living")
plt.ylabel("House prices")
plt.show()
# Out:
# C:\Users\KaKone\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %% [markdown]
# # Regression linear multiple

# %%
#feature extraction
x2=house_new[["bedrooms","bathrooms","sqft_living","sqft_lot","floors","grade","sqft_above","yr_built","sqft_living15","sqft_lot15"]]
#target_extraction
y2=house_new[["price"]]

# %%
#data spliting avec une taille de 25%
x_train2,x_test2,y_train2,y_test2=train_test_split(x2,y2,test_size=0.20,random_state = 0)

# %%
#Ajustement du modèl
model2=LinearRegression().fit(x_train2,y_train2)
R_carré = model2.score(x_test2, y_test2)
print(f"coefficient of determination: {R_carré}")
# Out:
# coefficient of determination: 0.6246170109088374

# %% [markdown]
# le coefficient R²=0,62 , cela veut dire que le modèl predit bien les resultat à 62%

# %%
y_pred = model2.predict(x_test2)

# %% [markdown]
# le modèle de regression linèaire multiple predit mieux les resultats que celui de regression linèaire simple

# %% [markdown]
# # Polynomial regression

# %%
from sklearn.preprocessing import PolynomialFeatures
poly_reg = PolynomialFeatures(degree = 2, include_bias=False)
poly_features=poly_reg.fit(x)
poly_features=poly_reg.transform(x)
poly_features.shape
# Out:
# (21613, 65)

# %%
x_train, x_test, y_train, y_test = train_test_split(poly_features, y, test_size=0.3, random_state=101)

# %%
#Training a Polynomial Regression Model
polymodel=LinearRegression()
polymodel.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
#Predicting Test Data¶
y_pred=polymodel.predict(x_test)

# %%
#Evaluating the Model

MAE_Poly = metrics.mean_absolute_error(y_test,y_pred)
MSE_Poly = metrics.mean_squared_error(y_test,y_pred)
RMSE_Poly = np.sqrt(MSE_Poly)
pd.DataFrame([MAE_Poly, MSE_Poly, RMSE_Poly],index=['MAE', 'MSE', 'RMSE'], columns=['metrics'])
# Out:
#            metrics
# MAE   1.304510e+05
# MSE   4.331823e+10
# RMSE  2.081303e+05

# %%
#Compare to the simple linear regression:

XS_train, XS_test, ys_train, ys_test = train_test_split(x1, y1, test_size=0.3, random_state=101)
simplemodel=LinearRegression()
simplemodel.fit(XS_train, ys_train)
ys_pred=simplemodel.predict(XS_test)

MAE_simple = metrics.mean_absolute_error(ys_test,ys_pred)
MSE_simple = metrics.mean_squared_error(ys_test,ys_pred)
RMSE_simple = np.sqrt(MSE_simple)


XM_train, XM_test, yM_train, yM_test = train_test_split(x2, y2, test_size=0.3, random_state=101)
Multmodel=model2
Multmodel.fit(XM_train, yM_train)
yM_pred=Multmodel.predict(XM_test)

MAE_mult = metrics.mean_absolute_error(yM_test,yM_pred)
MSE_mult = metrics.mean_squared_error(yM_test,yM_pred)
RMSE_mult = np.sqrt(MSE_mult)

pd.DataFrame({'Poly Metrics': [MAE_Poly, MSE_Poly, RMSE_Poly], 'Simple Metrics':[MAE_simple, MSE_simple,RMSE_simple],'Multiple Metrics':[MAE_mult, MSE_mult,RMSE_mult]}, index=['MAE', 'MSE', 'RMSE'])
# Out:
#       Poly Metrics  Simple Metrics  Multiple Metrics
# MAE   1.304510e+05    1.729282e+05      1.443890e+05
# MSE   4.331823e+10    6.872817e+10      5.263791e+10
# RMSE  2.081303e+05    2.621606e+05      2.294295e+05
