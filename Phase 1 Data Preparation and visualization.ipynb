# %%
import pandas as pd
data=pd.read_csv((r"C:\Users\DELL G5\Downloads\Final_Project_data\Cocoa_Yield_data.csv"),encoding='utf-8',sep =";")
data.head()
# Out:
#    hhmem_number  respondent_age  p1_respondent_gender  n_crops_produced  \
# 0           3.0              35                     1                 3
# 1           3.0              46                     0                 9
# 2           4.0              41                     1                 4
# 3          14.0              34                     0                12
# 4           7.0              32                     1                11
#
#    cocoa_land_used_ha  cocoa_prod_total_kgsha  fm_cocoa_lab_n_ha  \
# 0                 3.0               395.33331          74.666664
# 1                 3.0               179.20001          57.000000
# 2                 1.0               100.00000         107.999990
# 3                 1.0               550.00000          40.000000
# 4                 3.5               328.57144          23.857141
#
#    cocoa_gfert_yn  cocoa_lfert_yn  cocoa_manurecomp_yn  ...  cocoa_pest_yn  \
# ...

# %%
#/Display the summary statistics of the dataset using the describe() function #
data.describe()
# Out:
#        hhmem_number  respondent_age  p1_respondent_gender  n_crops_produced  \
# count    439.000000      446.000000            446.000000        446.000000
# mean       6.933941       46.363229              0.923767          6.502242
# std        3.694091       12.185934              0.265669          3.414279
# min        1.000000       22.000000              0.000000          1.000000
# 25%        4.000000       37.250000              1.000000          4.000000
# 50%        6.000000       46.000000              1.000000          6.000000
# 75%        9.000000       55.750000              1.000000          9.000000
# max       21.000000       90.000000              1.000000         15.000000
#
#        cocoa_land_used_ha  cocoa_prod_total_kgsha  fm_cocoa_lab_n_ha  \
# count          446.000000              446.000000         446.000000
# mean             4.235538              353.152575          40.935480
# std              2.989583              211.980001          19.417094
# ...

# %%
#Check the information of the dataset using the info() function.#
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 446 entries, 0 to 445
# Data columns (total 21 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   hhmem_number              439 non-null    float64
#  1   respondent_age            446 non-null    int64
#  2   p1_respondent_gender      446 non-null    int64
#  3   n_crops_produced          446 non-null    int64
#  4   cocoa_land_used_ha        446 non-null    float64
#  5   cocoa_prod_total_kgsha    446 non-null    float64
#  6   fm_cocoa_lab_n_ha         446 non-null    float64
#  7   cocoa_gfert_yn            446 non-null    int64
#  8   cocoa_lfert_yn            446 non-null    int64
#  9   cocoa_manurecomp_yn       446 non-null    int64
#  10  cocoa_herb_yn             446 non-null    int64
#  11  cocoa_pest_yn             446 non-null    int64
#  12  cocoa_fung_yn             446 non-null    int64
#  13  cocoa_training_5years_yn  446 non-null    int64
# ...

# %%
#On constate que la variable "hhmen_number" contient 7 valeur manquante. Nous allons remplacer par la médiane"
hh_numb_median = data['hhmem_number'].median()
data['hhmem_number'].fillna(hh_numb_median, inplace=True)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 446 entries, 0 to 445
# Data columns (total 21 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   hhmem_number              446 non-null    float64
#  1   respondent_age            446 non-null    int64
#  2   p1_respondent_gender      446 non-null    int64
#  3   n_crops_produced          446 non-null    int64
#  4   cocoa_land_used_ha        446 non-null    float64
#  5   cocoa_prod_total_kgsha    446 non-null    float64
#  6   fm_cocoa_lab_n_ha         446 non-null    float64
#  7   cocoa_gfert_yn            446 non-null    int64
#  8   cocoa_lfert_yn            446 non-null    int64
#  9   cocoa_manurecomp_yn       446 non-null    int64
#  10  cocoa_herb_yn             446 non-null    int64
#  11  cocoa_pest_yn             446 non-null    int64
#  12  cocoa_fung_yn             446 non-null    int64
#  13  cocoa_training_5years_yn  446 non-null    int64
# ...

# %%
import matplotlib.pyplot as plt
plt.hist(data['respondent_age'], bins=10, edgecolor='black');
plt.xlabel('Age');
plt.ylabel('count');

# %%
import matplotlib.pyplot as plt
plt.hist(data['p1_respondent_gender'], bins=2 , edgecolor='Red');
plt.xlabel('sex');
plt.ylabel('count');

# %%
import matplotlib.pyplot as plt
plt.hist(data['cocoa_prod_total_kgsha'], bins=10, edgecolor='red');
plt.xlabel('Ccoca_Yield');
plt.ylabel('count');

# %%
import seaborn as sns
import matplotlib.pyplot as plt

columns_to_visualize = ['hhmem_number', 'fm_cocoa_lab_n_ha', 'cocoa_land_used_ha']

# Create individual scatter plots for each pair with 'Price'
for column in columns_to_visualize:
    sns.scatterplot(x=column, y='cocoa_prod_total_kgsha', data=data)
    plt.title(f'Scatter plot between {column} and cocoa_prod_total_kgsha')
    plt.show()
